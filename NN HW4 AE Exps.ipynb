# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/nnHW4"
# Out:
# /content/drive/MyDrive/Colab Notebooks/nnHW4

# %% [markdown]
# # Cifar 10:

# %%
# !python AE.py
# Out:
# cuda:0
# Files already downloaded and verified
# Files already downloaded and verified
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             864
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#             Conv2d-4           [-1, 32, 32, 32]           9,216
#        BatchNorm2d-5           [-1, 32, 32, 32]              64
#               ReLU-6           [-1, 32, 32, 32]               0
#          AvgPool2d-7           [-1, 32, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          18,432
#        BatchNorm2d-9           [-1, 64, 16, 16]             128
#              ReLU-10           [-1, 64, 16, 16]               0
#            Conv2d-11           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-12           [-1, 64, 16, 16]             128
#              ReLU-13           [-1, 64, 16, 16]               0
#         AvgPool2d-14             [-1, 64, 8, 8]               0
#            Conv2d-15            [-1, 128, 8, 8]          73,728
#       BatchNorm2d-16            [-1, 128, 8, 8]             256
#              ReLU-17            [-1, 128, 8, 8]               0
#            Conv2d-18            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-19            [-1, 128, 8, 8]             256
#              ReLU-20            [-1, 128, 8, 8]               0
#         AvgPool2d-21            [-1, 128, 4, 4]               0
#            Conv2d-22            [-1, 256, 4, 4]         294,912
#       BatchNorm2d-23            [-1, 256, 4, 4]             512
#              ReLU-24            [-1, 256, 4, 4]               0
#            Conv2d-25            [-1, 256, 4, 4]         589,824
#       BatchNorm2d-26            [-1, 256, 4, 4]             512
#              ReLU-27            [-1, 256, 4, 4]               0
#            Conv2d-28            [-1, 512, 2, 2]       1,180,160
#       BatchNorm2d-29            [-1, 512, 2, 2]           1,024
#              Tanh-30            [-1, 512, 2, 2]               0
#         AvgPool2d-31            [-1, 512, 1, 1]               0
#   Shallow_Encoder-32            [-1, 512, 1, 1]               0
#   ConvTranspose2d-33            [-1, 256, 3, 3]       1,179,648
#       BatchNorm2d-34            [-1, 256, 3, 3]             512
#              Tanh-35            [-1, 256, 3, 3]               0
#   ConvTranspose2d-36            [-1, 128, 4, 4]         524,288
#       BatchNorm2d-37            [-1, 128, 4, 4]             256
#              ReLU-38            [-1, 128, 4, 4]               0
#   ConvTranspose2d-39             [-1, 64, 8, 8]         131,072
#       BatchNorm2d-40             [-1, 64, 8, 8]             128
#              ReLU-41             [-1, 64, 8, 8]               0
#   ConvTranspose2d-42           [-1, 32, 16, 16]          32,768
#       BatchNorm2d-43           [-1, 32, 16, 16]              64
#              ReLU-44           [-1, 32, 16, 16]               0
#   ConvTranspose2d-45           [-1, 16, 32, 32]           8,192
#       BatchNorm2d-46           [-1, 16, 32, 32]              32
#              Tanh-47           [-1, 16, 32, 32]               0
#            Conv2d-48            [-1, 3, 32, 32]              51
#           Sigmoid-49            [-1, 3, 32, 32]               0
#   Shallow_Decoder-50            [-1, 3, 32, 32]               0
# ================================================================
# Total params: 4,231,411
# Trainable params: 4,231,411
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.80
# Params size (MB): 16.14
# Estimated Total Size (MB): 19.96
# ----------------------------------------------------------------
# None
# classifier:
# CLF(
#   (fc1): Linear(in_features=512, out_features=128, bias=True)
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )
# trainL: 0.00646 - testL: 0.00641:  17% 10/60 [04:43<23:41, 28.42s/it]/content/drive/MyDrive/Colab Notebooks/nnHW4/utils.py:26: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axs = plt.subplots(nrows=8, ncols=17, figsize=(w, h),
# trainL: 0.00283 - testL: 0.00300: 100% 60/60 [28:27<00:00, 28.46s/it]

# %% [markdown]
# # Get Data

# %%
# !ls
# Out:
#  AE_models.py	 extract_domainnet_groups.ipynb   real.zip
#  AE.py		 GAN_models.py			  real.zip.1
#  CIFAR10	'GANs results'			 'results to report'
#  data_utils.py	'NN HW4 AE Exps.ipynb'		 'TSNE cifar10 explore.ipynb'
#  DCGAN.py	'NN HW4 DCGAN Exps.ipynb'	  utils.py
#  DomainNet	'old exp'
#  exps		 __pycache__

# %%
# !wget http://csr.bu.edu/ftp/visda/2019/multi-source/real.zip

# %%
# !wget http://csr.bu.edu/ftp/visda/2019/multi-source/groundtruth/painting.zip
# Out:
# --2023-07-05 11:45:18--  http://csr.bu.edu/ftp/visda/2019/multi-source/groundtruth/painting.zip
# Resolving csr.bu.edu (csr.bu.edu)... 128.197.11.70
# Connecting to csr.bu.edu (csr.bu.edu)|128.197.11.70|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3679366174 (3.4G) [application/zip]
# Saving to: ‘painting.zip’
#
# painting.zip        100%[===================>]   3.43G  12.7MB/s    in 4m 42s
#
# 2023-07-05 11:50:00 (12.5 MB/s) - ‘painting.zip’ saved [3679366174/3679366174]

# %%
mammals = {
    'name': 'mammals',
    'list_to_extract': [
        'cat',
        'hedgehog',
        'lion',
        'panda',
        # 'raccoon', #
        # 'squirrel', #
        'zebra',
        'bear', ##
        'cow',
        'elephant',
        'horse',
        # 'monkey', #
        'pig',
        'rhinoceros',
        'tiger',
        # 'camel',
        'dog', ##
        'giraffe',
        'kangaroo',
        # 'mouse', #
        # 'rabbit', #
        'sheep',
    ]
}

# %%
from typing import Dict
import zipfile as zipfile

def unzip_classes(what_to_extract: Dict, domain: str):
    zip_ref = zipfile.ZipFile(f"/content/drive/MyDrive/Colab Notebooks/nnHW4/{domain}.zip", 'r')
    namelist=zip_ref.namelist()
    list_to_extract = what_to_extract['list_to_extract']
    name_to_extract = what_to_extract['name']
    filtered_namelist = [string for string in namelist if any(substring == string.split('/')[1] for substring in list_to_extract)]

    temp = [string for string in filtered_namelist if '.jpg' not in string]
    print(temp)

    print(len(temp))
    print(len(list_to_extract))

    zip_ref.extractall(path=f'DomainNet/{domain}/{name_to_extract}', members = filtered_namelist)

# unzip_classes(mammals, 'real')
# Out:
# ['real/bear/', 'real/cat/', 'real/cow/', 'real/dog/', 'real/elephant/', 'real/giraffe/', 'real/hedgehog/', 'real/horse/', 'real/kangaroo/', 'real/lion/', 'real/panda/', 'real/pig/', 'real/rhinoceros/', 'real/sheep/', 'real/tiger/', 'real/zebra/']
# 16
# 16

# %%
# unzip_classes(mammals, 'painting')
# Out:
# ['painting/bear/', 'painting/cat/', 'painting/cow/', 'painting/dog/', 'painting/elephant/', 'painting/giraffe/', 'painting/hedgehog/', 'painting/horse/', 'painting/kangaroo/', 'painting/lion/', 'painting/panda/', 'painting/pig/', 'painting/rhinoceros/', 'painting/sheep/', 'painting/tiger/', 'painting/zebra/']
# 16
# 16

# %% [markdown]
# # AE domainnnet

# %%
# !python AE.py
# Out:
# cuda:0
# 10522
# 5482
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 64, 64]             432
#        BatchNorm2d-2           [-1, 16, 64, 64]              32
#               ReLU-3           [-1, 16, 64, 64]               0
#             Conv2d-4           [-1, 16, 64, 64]           2,304
#        BatchNorm2d-5           [-1, 16, 64, 64]              32
#               ReLU-6           [-1, 16, 64, 64]               0
#          AvgPool2d-7           [-1, 16, 32, 32]               0
#             Conv2d-8           [-1, 32, 32, 32]           4,608
#        BatchNorm2d-9           [-1, 32, 32, 32]              64
#              ReLU-10           [-1, 32, 32, 32]               0
#            Conv2d-11           [-1, 32, 32, 32]           9,216
#       BatchNorm2d-12           [-1, 32, 32, 32]              64
#              ReLU-13           [-1, 32, 32, 32]               0
#         AvgPool2d-14           [-1, 32, 16, 16]               0
#            Conv2d-15           [-1, 64, 16, 16]          18,432
#       BatchNorm2d-16           [-1, 64, 16, 16]             128
#              ReLU-17           [-1, 64, 16, 16]               0
#            Conv2d-18           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-19           [-1, 64, 16, 16]             128
#              ReLU-20           [-1, 64, 16, 16]               0
#         AvgPool2d-21             [-1, 64, 8, 8]               0
#            Conv2d-22            [-1, 128, 8, 8]          73,728
#       BatchNorm2d-23            [-1, 128, 8, 8]             256
#              ReLU-24            [-1, 128, 8, 8]               0
#            Conv2d-25            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-26            [-1, 128, 8, 8]             256
#              ReLU-27            [-1, 128, 8, 8]               0
#         AvgPool2d-28            [-1, 128, 4, 4]               0
#            Conv2d-29            [-1, 256, 4, 4]         294,912
#       BatchNorm2d-30            [-1, 256, 4, 4]             512
#             PReLU-31            [-1, 256, 4, 4]               1
#            Conv2d-32            [-1, 512, 2, 2]       1,180,160
#       BatchNorm2d-33            [-1, 512, 2, 2]           1,024
#              Tanh-34            [-1, 512, 2, 2]               0
# AdaptiveAvgPool2d-35            [-1, 512, 1, 1]               0
# Shallow_Encoder_64-36            [-1, 512, 1, 1]               0
#   ConvTranspose2d-37            [-1, 256, 3, 3]       1,179,648
#       BatchNorm2d-38            [-1, 256, 3, 3]             512
#             PReLU-39            [-1, 256, 3, 3]               1
#   ConvTranspose2d-40            [-1, 128, 4, 4]         524,288
#       BatchNorm2d-41            [-1, 128, 4, 4]             256
#              ReLU-42            [-1, 128, 4, 4]               0
#   ConvTranspose2d-43             [-1, 64, 8, 8]         131,072
#       BatchNorm2d-44             [-1, 64, 8, 8]             128
#              ReLU-45             [-1, 64, 8, 8]               0
#   ConvTranspose2d-46           [-1, 32, 16, 16]          32,768
#       BatchNorm2d-47           [-1, 32, 16, 16]              64
#              ReLU-48           [-1, 32, 16, 16]               0
#   ConvTranspose2d-49           [-1, 16, 32, 32]           8,192
#       BatchNorm2d-50           [-1, 16, 32, 32]              32
#              ReLU-51           [-1, 16, 32, 32]               0
#   ConvTranspose2d-52            [-1, 8, 64, 64]           2,048
#       BatchNorm2d-53            [-1, 8, 64, 64]              16
#              Tanh-54            [-1, 8, 64, 64]               0
#            Conv2d-55            [-1, 3, 64, 64]              27
#           Sigmoid-56            [-1, 3, 64, 64]               0
# Shallow_Decoder_64-57            [-1, 3, 64, 64]               0
# ================================================================
# Total params: 3,649,661
# Trainable params: 3,649,661
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 7.79
# Params size (MB): 13.92
# Estimated Total Size (MB): 21.76
# ----------------------------------------------------------------
# None
# trainL: 0.02246 - testL: 0.02626:  12% 6/50 [11:44<1:14:11, 101.16s/it]/content/drive/MyDrive/Colab Notebooks/nnHW4/utils.py:61: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax1 = plt.subplots(nrows = 1, ncols = 1, figsize=[7, 6], dpi=100)
# trainL: 0.01375 - testL: 0.01816:  44% 22/50 [37:00<46:48, 100.31s/it]

# %% [markdown]
# # Domainnet GAN

# %%
# !python DCGAN.py

# %%
64 * 8 * 4 * 4 * 128
# Out:
# 1048576

# %%
from google.colab import runtime
runtime.unassign()

# %%
# /content/drive/MyDrive/Colab Notebooks/nnHW4/exps/models/Shallow_CNN_AE.pt
